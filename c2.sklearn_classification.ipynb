# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# %%
DATA_JSON_FILE = 'SpamData\\01_Processing\\email-text-data.json'

# %%
data = pd.read_json(DATA_JSON_FILE)

# %%
data.head()
# Out:
#       CATEGORY                                            MESSAGE  \
# 0            1  Dear Homeowner,\n\n \n\nInterest Rates are at ...
# 1            1  ATTENTION: This is a MUST for ALL Computer Use...
# 10           1  Dear Consumers, Increase your Business Sales! ...
# 100          1  <HTML><TABLE WIDTH=100% BORDER=0 CELLPADDING=0...
# 1000         1  \n\nThe Internet's Online Pharmacy\n\n\n\nViag...
#
#                                    FILE_NAME
# 0     00249.5f45607c1bffe89f60ba1ec9f878039a
# 1     00373.ebe8670ac56b04125c25100a36ab0510
# 10    00159.b16f070a576c2eb1533aa9e2cf8e6b77
# 100   00406.05e2214fea602970426862295f9b4a2e
# 1000  00056.64a6ee24c0b7bf8bdba8340f0a3aafda

# %%
vectorizer = CountVectorizer(stop_words='english')

# %%
all_features = vectorizer.fit_transform(data.MESSAGE)

# %%
all_features.shape
# Out:
# (5796, 102694)

# %%
vectorizer.vocabulary_
# Out:
# {'dear': 32719,
#  'homeowner': 48034,
#  'rates': 76350,
#  'lowest': 59365,
#  'point': 72297,
#  '40': 7824,
#  'years': 98506,
#  'help': 47200,
#  'best': 23129,
#  'rate': 76347,
#  'situation': 82318,
#  'matching': 60930,
#  'needs': 64750,
#  'hundreds': 48607,
#  'lenders': 58021,
#  'home': 48006,
#  'improvement': 51399,
#  'refinance': 77074,
#  'second': 80968,
#  'mortgage': 63026,
#  'equity': 38990,
#  'loans': 59058,
#  'perfect': 70478,
#  'credit': 30975,
#  'service': 81359,
#  '100': 1496,
#  'free': 42773,
#  'owners': 68715,
#  'new': 64988,
#  'buyers': 25617,
#  'obligation': 66813,
#  'just': 55049,
#  'quick': 75547,
#  'simple': 82172,
#  'form': 42425,
#  'jump': 55000,
#  'start': 84135,
#  'future': 43330,
#  'plans': 71939,
#  'today': 88039,
#  'visit': 92921,
#  'http': 48497,
#  '61': 10092,
#  '145': 2275,
#  '116': 1873,
#  '186': 2748,
#  'user0201': 91339,
#  'index': 51639,
#  'asp': 20429,
#  'afft': 17606,
#  'qm10': 75108,
#  'unsubscribe': 90955,
#  'light': 58472,
#  'watch': 94281,
#  'attention': 20740,
#  'computer': 29755,
#  'users': 91367,
#  'special': 83501,
#  'package': 69119,
#  'deal': 32703,
#  'norton': 65833,
#  'systemworks': 85743,
#  '2002': 3508,
#  'software': 83094,
#  'suite': 85010,
#  'professional': 73364,
#  'edition': 37555,
#  'includes': 51529,
#  'yes': 98554,
#  'feature': 41058,
#  'packed': 69127,
#  'utilities': 91474,
#  'low': 59355,
#  'price': 73136,
#  'protect': 73612,
#  'unwanted': 91011,
#  'hazardous': 46863,
#  'viruses': 92887,
#  'secure': 81012,
#  'private': 73228,
#  'valuable': 92057,
#  'information': 51875,
#  'allow': 18722,
#  'transfer': 88556,
#  'files': 41540,
#  'send': 81178,
#  'mails': 60404,
#  'safely': 80079,
#  'backup': 22191,
#  'data': 32319,
#  'easily': 37275,
#  'improve': 51396,
#  'pc': 69756,
#  'performance': 70486,
#  'superior': 85124,
#  'integral': 52274,
#  'diagnostics': 33895,
#  'great': 45565,
#  '300': 5594,
#  'combined': 29424,
#  'retail': 77958,
#  'value': 92060,
#  '29': 4793,
#  '99': 13970,
#  'shipping': 81777,
#  'don': 34992,
#  'fall': 40613,
#  'prey': 73130,
#  'destructive': 33432,
#  'hackers': 46445,
#  'delay': 33048,
#  'copy': 30455,
#  'euro': 39422,
#  'specialdiscounts4u': 83503,
#  'com': 29405,
#  'email': 38216,
#  'screened': 80746,
#  'filtered': 41575,
#  'house': 48262,
#  'opt': 67895,
#  'compliance': 29680,
#  'state': 84171,
#  'laws': 57670,
#  'wish': 95691,
#  'mailing': 60381,
#  'lists': 58733,
#  'thousands': 87420,
#  'providers': 73664,
#  'dvd': 36559,
#  'optoutd': 67953,
#  'html': 48472,
#  'consumers': 30189,
#  'increase': 51582,
#  'business': 25553,
#  'sales': 80134,
#  'targeting': 86354,
#  'millions': 62118,
#  'mail': 60312,
#  '25': 4433,
#  'million': 62115,
#  'emails': 38248,
#  'bulk': 25419,
#  '150': 2340,
#  '00': 0,
#  'super': 85106,
#  'act': 16884,
#  'fresh': 42894,
#  'addresses': 17113,
#  'bring': 25039,
#  'incredible': 51589,
#  'results': 77941,
#  'really': 76664,
#  'want': 94159,
#  'word': 96017,
#  'regarding': 77145,
#  'services': 81361,
#  'products': 73349,
#  'way': 94335,
#  'period': 70505,
#  'advertising': 17349,
#  'newsgroups': 65057,
#  'good': 45236,
#  'competing': 29632,
#  'ads': 17283,
#  'customer': 31476,
#  'ad': 16973,
#  'midst': 62039,
#  'classifieds': 28619,
#  'work': 96033,
#  'web': 94964,
#  'site': 82284,
#  'takes': 86235,
#  'visitors': 92928,
#  'banners': 22387,
#  'expensive': 39909,
#  'iffy': 50286,
#  'zine': 100401,
#  'better': 23177,
#  'huge': 48542,
#  'list': 58680,
#  'search': 80915,
#  'engines': 38592,
#  'buried': 25502,
#  'directly': 34167,
#  'contact': 30198,
#  'potential': 72648,
#  'customers': 31479,
#  'likely': 58507,
#  'time': 87625,
#  'read': 76610,
#  'offer': 67158,
#  'easy': 37289,
#  'reading': 76627,
#  'searching': 80930,
#  'countless': 30653,
#  'postings': 72618,
#  'divided': 34549,
#  'groups': 45719,
#  'compressed': 29721,
#  'use': 91315,
#  'names': 64368,
#  'right': 78422,
#  'cd': 27206,
#  'order': 68036,
#  '72': 11179,
#  'hours': 48261,
#  'recieve': 76822,
#  'bonuses': 24500,
#  '48': 8295,
#  'technical': 86636,
#  'support': 85179,
#  'bonus': 24498,
#  'receive': 76783,
#  'additional': 17082,
#  'rom': 78893,
#  'deliverable': 33092,
#  'general': 44238,
#  'internet': 52404,
#  '2000': 3488,
#  'books': 24525,
#  'reports': 77644,
#  'manuals': 60692,
#  'reprint': 77668,
#  'resale': 77738,
#  'rights': 78433,
#  'produce': 73330,
#  'pennies': 70418,
#  'resell': 77762,
#  'big': 23545,
#  'dollars': 34945,
#  'mass': 60896,
#  'mailer': 60354,
#  'delivery': 33097,
#  'operating': 67829,
#  'instructions': 52224,
#  'informational': 51876,
#  'guide': 45922,
#  'need': 64740,
#  'started': 84137,
#  'worth': 96113,
#  'limited': 58543,
#  'supplies': 85173,
#  'dream': 36168,
#  'unbelievable': 90434,
#  'ordering': 68042,
#  'check': 27852,
#  'fax': 40806,
#  'card': 26760,
#  'info': 51836,
#  'day': 32411,
#  'received': 76784,
#  '3pm': 7646,
#  'central': 27414,
#  'place': 71899,
#  '308': 5639,
#  '650': 10287,
#  '5905': 9415,
#  'ext': 40021,
#  '121': 1980,
#  '415': 7964,
#  '873': 12769,
#  '2700': 4623,
#  'number': 66246,
#  'orders': 68044,
#  '__________________________________________': 14692,
#  'simply': 82183,
#  'cut': 31495,
#  'paste': 69579,
#  'print': 73183,
#  'ez': 40163,
#  'office': 67173,
#  'effect': 37696,
#  'seven': 81425,
#  'days': 32422,
#  'regular': 77202,
#  '250': 4434,
#  'tomorrow': 88121,
#  'accept': 16644,
#  'visa': 92906,
#  'mastercard': 60913,
#  'amex': 18968,
#  'disc': 34238,
#  'checks': 27877,
#  '_____yes': 14740,
#  'include': 51527,
#  'disk': 34359,
#  'plus': 72122,
#  '093': 866,
#  '808': 12086,
#  'indicated': 51684,
#  'missed': 62320,
#  'hour': 48259,
#  'clean': 28651,
#  '_____oop': 14739,
#  'specials': 83517,
#  'select': 81106,
#  'option': 67936,
#  '____i': 14741,
#  'like': 58501,
#  'fedex': 41085,
#  'overnight': 68599,
#  'including': 51532,
#  '15': 2339,
#  'hawaii': 46838,
#  'alaska': 18536,
#  '20': 3486,
#  'canada': 26606,
#  'international': 52395,
#  'add': 17059,
#  'total': 88259,
#  '10': 1495,
#  'sorry': 83254,
#  'continental': 30269,
#  'carefully': 26791,
#  'note': 65874,
#  'shipped': 81774,
#  'complete': 29666,
#  'signature': 82080,
#  'exceptions': 39688,
#  'name____________________________________________________': 64361,
#  'company': 29579,
#  'name____________________________________________': 64357,
#  'address_________________________________________________': 17104,
#  'ship': 81770,
#  'street': 84556,
#  'boxes': 24708,
#  'city': 28382,
#  'zip________________________________________': 100410,
#  'phone': 71311,
#  'number____________________________________________': 66249,
#  'required': 77713,
#  'tracking': 88473,
#  'address___________________________________________': 17102,
#  'case': 26890,
#  'question': 75527,
#  'confirmation': 29937,
#  '24': 4349,
#  'hrs': 48405,
#  'type': 89371,
#  '______visa': 14737,
#  '_____mastercard': 14738,
#  '______amex': 14734,
#  '______disc': 14736,
#  'expiration': 39931,
#  'date________________________________________': 32347,
#  'card___________________________________________': 26766,
#  '___________________': 14673,
#  'date': 32345,
#  'x__________________': 96908,
#  'x_________________________________': 96909,
#  'understand': 90570,
#  'purchasing': 74128,
#  'address': 17095,
#  'authorize': 20929,
#  'charge': 27776,
#  'rented': 77551,
#  'included': 51528,
#  'considered': 30093,
#  'financial': 41598,
#  'transaction': 88547,
#  'responsibility': 77876,
#  'comply': 29691,
#  'applicable': 19773,
#  'local': 59075,
#  'area': 20071,
#  'opened': 67785,
#  'returned': 78027,
#  'defective': 32949,
#  'replaced': 77600,
#  'product': 73337,
#  'to1': 88012,
#  'forms': 42452,
#  'original': 68112,
#  'draft': 36117,
#  'exact': 39641,
#  'held': 47176,
#  'bank': 22360,
#  'clearance': 28670,
#  'make': 60515,
#  'payable': 69686,
#  'offlist': 67192,
#  'reply': 77619,
#  'message': 61680,
#  'mailings': 60385,
#  'mailto': 60412,
#  'trudymail2002': 88875,
#  'themail': 87230,
#  'subject': 84789,
#  'offitnow': 67189,
#  'table': 86120,
#  'width': 95488,
#  'border': 24581,
#  'cellpadding': 27375,
#  'cellspacing': 27383,
#  'tr': 88442,
#  'td': 86548,
#  'align': 18634,
#  'center': 27405,
#  'valign': 92046,
#  'middle': 62022,
#  'bgcolor': 23297,
#  '0a0a5a': 914,
#  'href': 48390,
#  'www': 96531,
#  'freepornsecrets': 42826,
#  'net': 64868,
#  'bnr': 24325,
#  '3001j86020': 5599,
#  'target': 86349,
#  '_blank': 14794,
#  'font': 42257,
#  'color': 29367,
#  'ffff00': 41311,
#  'size': 82347,
#  'face': 40498,
#  'geneva': 44275,
#  'arial': 20116,
#  'helvetica': 47220,
#  'san': 80206,
#  'serif': 81304,
#  'strong': 84630,
#  'access': 16655,
#  'xxx': 97882,
#  'porn': 72495,
#  'br': 24813,
#  '550': 9237,
#  'colspan': 29390,
#  'img': 51212,
#  'src': 83872,
#  'art': 20230,
#  'hc_fps_01': 46907,
#  'jpg': 54782,
#  'height': 47157,
#  '112': 1827,
#  'hc_fps_02': 46908,
#  'gif': 44644,
#  '104': 1693,
#  '231': 4231,
#  'hc_fps_03': 46909,
#  '339': 5893,
#  'hc_fps_04': 46910,
#  '107': 1727,
#  'hc_fps_05': 46911,
#  '57': 9340,
#  'instant': 52197,
#  'hardcore': 46679,
#  'div': 34529,
#  'times': 87641,
#  'roman': 78896,
#  '710000': 11131,
#  'removed': 77482,
#  'remove': 77467,
#  'hxvwnj3q': 48750,
#  'online': 67665,
#  'pharmacy': 71227,
#  'viagra': 92673,
#  'xenical': 97150,
#  'propecia': 73532,
#  'claritin': 28598,
#  'celbrex': 27340,
#  'renova': 77543,
#  'zyban': 101346,
#  'prescriptions': 73036,
#  'approved': 19837,
#  'panel': 69308,
#  'licensed': 58407,
#  'medical': 61431,
#  'doctors': 34861,
#  'approval': 19831,
#  'doctor': 34857,
#  'medication': 61435,
#  'door': 35041,
#  'internets': 52407,
#  'clicking': 28730,
#  'link': 58601,
#  'pharm5': 71219,
#  'onchina': 67634,
#  'unlist4me': 90808,
#  'yahoo': 98304,
#  '_nextpart_000_00b0_35c58d0e': 14992,
#  'd7267b06': 32026,
#  'content': 30249,
#  'text': 86991,
#  'charset': 27796,
#  'iso': 53094,
#  '8859': 12828,
#  'encoding': 38472,
#  'base64': 22487,
#  'pgh0bww': 70913,
#  'dqo8ym9ket4ncjxmb250ignvbg9ypsjmzmzmzmyipm1hcnrpbmv6': 35564,
#  'pc9mb250pg0kpha': 69922,
#  'ww91cibob21lihjlzmluyw5jzsbsb2fuiglzigfwchjv': 96492,
#  'dmvkitxicj48l3a': 34762,
#  'pgjypg0kpha': 70966,
#  'vg8gz2v0ihlvdxigyxbwcm92zwqgyw1v': 92572,
#  'dw50idxhighyzwy9imh0dha6ly8ymdaumziumy4xmjevaw5kzxguahrtij5n': 36598,
#  'bw0kagvyztwvyt4upc9wpg0kpgjypjxicj48yni': 25662,
#  'pgjypjxicj48yni': 70984,
#  'pgjy': 70924,
#  'pjxicj48yni': 71796,
#  'vg8gymugzxhjbhvkzwqgznjvbsbmdxj0agvyig5vdgljzxmg': 92571,
#  'pgegahjlzj0iahr0cdovlziwmc4zmi4zljeyms9yzw1vdmuuahrtbci': 70899,
#  'z28n': 99664,
#  'cmhlcmu8l2e': 28936,
#  'ljwvcd4ncjxmb250ignvbg9ypsjmzmzmzmyipm1hcnrpbmv6': 58850,
#  'pc9mb250pg0kpc9ib2r5pg0kpgzvbnqgy29sb3i9imzmzmzmzii': 69921,
#  'mwdhdgun': 63851,
#  'cjwvahrtbd4ncja0ntrzdlfeoc00njdcwlldmjyymhhiemc2ltk2bdi3': 28479,
#  'head': 47011,
#  'meta': 61701,
#  'equiv': 38991,
#  'language': 57500,
#  'en': 38432,
#  'windows': 95603,
#  '1252': 2025,
#  'generator': 44258,
#  'microsoft': 62003,
#  'frontpage': 43005,
#  'progid': 73406,
#  'editor': 37557,
#  'document': 34867,
#  'title': 87725,
#  'earn': 37247,
#  'high': 47526,
#  'commissions': 29515,
#  'booking': 24516,
#  'body': 24390,
#  '600': 10039,
#  '491': 8349,
#  '34': 5921,
#  '87': 12742,
#  'ntmllc': 66169,
#  'mailpound': 60401,
#  'images': 51166,
#  'ntm2_ani': 66168,
#  '120': 1956,
#  '74': 11261,
#  '33': 5831,
#  '31': 5688,
#  'hspace': 48437,
#  'mpart4_tm': 63192,
#  '190': 2801,
#  'span': 83450,
#  'style': 84723,
#  'black': 23893,
#  'northstar': 65828,
#  'travel': 88650,
#  'media': 61413,
#  'llc': 58900,
#  'mso': 63439,
#  'spacerun': 83369,
#  'nbsp': 64561,
#  'division': 34560,
#  'smart': 82749,
#  'technologies': 86652,
#  'provide': 73660,
#  'professionals': 73369,
#  'marketing': 60798,
#  'solutions': 83156,
#  'hr': 48373,
#  '000080': 37,
#  'agents': 17768,
#  'outside': 68496,
#  'independent': 51631,
#  'corporate': 30516,
#  '224': 4070,
#  'pssst': 73837,
#  'htm': 48469,
#  '350': 5988,
#  '200': 3487,
#  'vspace': 93433,
#  'click': 28719,
#  '62': 10140,
#  'trademark': 88489,
#  'ffffff': 41323,
#  '209': 3742,
#  '202': 3687,
#  '177': 2653,
#  '149': 2312,
#  'eimages': 37908,
#  'paw': 69680,
#  '331172': 5847,
#  'messages': 61684,
#  'default': 32932,
#  'cid': 28271,
#  'amp': 19047,
#  'sid': 82008,
#  'fork': 42412,
#  'xent': 97154,
#  'class': 28606,
#  'msoheader': 63443,
#  'tab': 86113,
#  'stops': 84457,
#  '5in': 9662,
#  'questions': 75532,
#  'comments': 29493,
#  'supplier': 85171,
#  'inquiries': 52082,
#  'mailman': 60393,
#  'listinfo': 58724,
#  '_nextpart_000_00e4_86e61e0a': 15029,
#  'b5488e11': 21974,
#  'pcetlsbzyxzlzcbmcm9tihvybd0omdaymilodhrwoi8vaw50zxjuzxquzs1t': 70132,
#  'ywlsic0tpg0kpgh0bww': 99391,
#  'dqo8ym9ket4ncjxibg9ja3f1b3rlpg0kica8ccbh': 35563,
#  'bglnbj0ibgvmdci': 23324,
#  'pgzvbnqgc2l6zt0inii': 71106,
#  'pgzvbnqgy29sb3i9iimwmdaw': 71119,
#  'rkyipln0b2nrie1hcmtldcbcbhvlcybnb3qgew91igrvd24': 78631,
#  'pc9mb250pizu': 69926,
#  'ynnwozwvzm9udd48yni': 98927,
#  'dqogidxicj4nciagpgzvbnqgc2l6zt0insigy29s': 35908,
#  'b3i9iingrjawmdaipkxvb2tpbmcgzm9yigegdmlhymxligfuzcbszwdpdglt': 21846,
#  'yxrligfsdgvybmf0axzlpyzuynnwozwvzm9udd48zm9udcbzaxplpsi0ij48': 99517,
#  'yni': 98913,
#  'dqogidwvzm9udd48yni': 35892,
#  'dqogidxmb250ihnpemu9ijqipldoyxqgzg8g': 35911,
#  'ew91ihroaw5rihdpbgwgagfwcgvuihrvihvubgvhzgvkigdhc29saw5lihby': 39572,
#  'awnlcybizxr3zwvuig5vdybhbmqgdghpcybzdw1tzxi': 21309,
#  'jm5ic3a7pgjypg0k': 54499,
#  'ica8yni': 49336,
#  'dqogierpzcb5b3uga25vdyb0agf0ihrozxjlighhc24ndcbizwvu': 35925,
#  'igegbmv3ihjlzmluzxj5igj1awx0igluihrozsbvbml0zwqgu3rhdgvziglu': 50411,
#  'ig92zxigmjagewvhcnm': 50380,
#  'jm5ic3a7pgjypg0kica8yni': 54500,
#  'dqogiervihlvdsbr': 35926,
#  'bm93ihroyxqgew91ignhbib0cmfkzsbvchrpb25zig9uihvubgvhzgvkigdh': 24152,
#  'c29saw5lignvbnryywn0cybvbib0agugtmv3iflvcmsgtwvyy2fudglszsbf': 26053,
#  'egnoyw5nzswnciagysbnb3zlcm5tzw50ihjlz3vsyxrlzcblegnoyw5nzt8g': 37790,
#  'ifdligfyzsb0agugchjvzmvzc2lvbmfscyb3ag8gc3bly2lhbgl6zsbpbib0': 50279,
#  'agvzzsbtyxjrzxrzigfuzcb0cmfkzsb0agvtig9uigegcmvndwxhcibiyxnp': 17937,
#  'cy4mbmjzcds8yni': 31669,
#  'dqogidxicj4nciagumvjzwl2zsb5b3vyigzyzwugcmvw': 35909,
#  'b3j0lcbpbmnsdwrpbmcgdghligjvb2tszxqgiji2ifbsywluiexhbmd1ywdl': 21859,
#  'iefuc3dlcnmgb24gt3b0aw9ucybucmfkaw5nii4mbmjzcds8yni': 50189,
#  'dqogidxi': 35905,
#  'cj4nciagr2v0ihrozsbjagfydhmsigdyyxbocybhbmqgdghlihnwzwnpywwg': 28442,
#  'cmvwb3j0ig9uifvubgvhzgvkiedhc29saw5lic0gu3vtbwvyidiwmdiujm5i': 29018,
#  'c3a7pgjypg0kicbgdxr1cmvzigfuzcbvchrpb25zihryywrpbmcgaw52b2x2': 26140,
#  'zsbzdwjzdgfudglhbcbyaxnrig9migxvc3mgyw5kiglzig5vdcbzdwl0ywjs': 100878,
#  'zsbmb3igzxzlcnlvbmuujm5ic3a7pgjypg0kica8yni': 100852,
#  'dqogiexlyxjuighv': 35927,
#  'dybvchrpb25zihryywrpbmcgy2fuihbvc2l0aw9uihlvdsbpbib0aglzigft': 36752,
#  'yxppbmcgbwfya2v0lizuynnwozxicj4nciagpgjypg0kica8ysbocmvmpsjo': 99502,
#  'dhrwoi8vd3d3lmludmvzdg1lbnq0ds5jb20vu3bly2lhbfjlcg9ydc8ipkns': 33857,
#  'awnrighlcmu8l2e': 21312,
#  'igfuzcb5b3ugd2lsbcbyzwnlaxzlihrozsbvbmxlywrl': 50440,
#  'zcbhyxnvbgluzsbzcgvjawfsihjlcg9ydc4mbmjzcds8yni': 99991,
#  'dqogicq1ldaw': 35887,
#  'mcb3awxsihb1cmnoyxnligzpdmugvw5szwfkzwqgr2fzb2xpbmugb3b0aw9u': 61142,
#  'ignvbnryywn0cy4mbmjzcds8yni': 50539,
#  'dqogie1pbmltdw0gjdusmdawigludmvz': 35922,
#  'dg1lbnqujm5ic3a7pgjypg0kicbuywtligfkdmfudgfnzsbvzib3agf0ihdl': 33599,
#  'igjlbglldmugaxmgyw4gb3v0c3rhbmrpbmcgaw52zxn0bwvudcbvchbvcnr1': 50475,
#  'bml0esembmjzcds8yni': 24213,
#  'dqogidxicj4nciagpgegahjlzj0iahr0cdovl3d3': 35907,
#  'dy5pbnzlc3rtzw50nhuuy29tl1nwzwnpywxszxbvcnqvij5dbgljaybizxjl': 36742,
#  'ie5pvye8l2e': 50161,
#  'dqogidwvzm9udd48zm9udcbz': 35893,
#  'axplpsizij48ysbocmvmpsjodhrwoi8vd3d3lmludmvzdg1lbnq0ds5jb20v': 21442,
#  'dgfrzw1lb2zmlyi': 33657,
#  'q2xpy2sgsgvyzsbubybizsb0ywtlbibvzmygdghligxp': 74523,
#  'c3qhdqogidwvyt48l2zvbnq': 26175,
#  'pc9wpg0kpc9ibg9ja3f1b3rlpg0kdqo8l2jv': 70075,
#  'zhk': 100294,
#  'dqoncjwvahrtbd4ncg0kdqo3nzuxuxnzzjytntgyv3jfudu3odzwaklg': 35989,
#  'ns0znzjvumznmgwzmw': 66052,
#  'barrister': 22472,
#  'adewale': 17134,
#  'coker': 29272,
#  'chambers': 27701,
#  'legal': 57964,
#  'practitioners': 72822,
#  'notary': 65870,
#  'public': 74013,
#  'blk': 24016,
#  '804': 12053,
#  'law': 57653,
#  'building': 25394,
#  'lagos': 57421,
#  'nigeria': 65310,
#  'kind': 56137,
#  'request': 77707,
#  'assistance': 20504,
#  'humble': 48581,
#  'pleasure': 72016,
#  'write': 96262,
#  'letter': 58092,
#  'irrespective': 52967,
#  'fact': 40520,
#  'know': 56461,
#  'reliable': 77353,
#  'trustworthy': 88907,
#  'person': 70605,
#  'handle': 46591,
#  'confidential': 29898,
#  'nature': 64483,
#  'family': 40651,
#  'lawyer': 57675,
#  'military': 62098,
#  'rule': 79415,
#  'sani': 80243,
#  'abacha': 16312,
#  'died': 33967,
#  'suddenly': 84956,
#  'power': 72689,
#  'ago': 17848,
#  'untimely': 90987,
#  'demise': 33139,
#  'suffered': 84969,
#  'lot': 59304,
#  'harassment': 46663,
#  'regimes': 77164,
#  'succeeded': 84907,
#  'regime': 77162,
#  'present': 73040,
#  'civilian': 28393,
#  'government': 45327,
#  'enemies': 38543,
#  'recently': 76800,
#  'wife': 95498,
#  'banned': 22375,
#  'traveling': 88655,
#  'kano': 55544,
#  'arrest': 20197,
#  'eldest': 38041,
#  'son': 83198,
#  'detention': 33461,
#  'money': 62840,
#  'recovered': 76895,
#  'mrs': 63319,
#  'death': 32725,
#  'husband': 48647,
#  'sums': 85057,
#  'hard': 46674,
#  'currencies': 31420,
#  'able': 16402,
#  'country': 30655,
#  'safe': 80067,
#  'keeping': 55778,
#  'tune': 89091,
#  '50': 8926,
#  'north': 65816,
#  'american': 18954,
#  'interested': 52352,
#  'prepare': 73004,
#  'beneficiary': 23037,
#  'funds': 43281,
#  'share': 81646,
#  'security': 81026,
#  'risk': 78497,
#  'involved': 52636,
#  'project': 73450,
#  'confidant': 29891,
#  'secret': 80981,
#  'prepared': 73005,
#  'pending': 70400,
#  'approach': 19819,
#  'await': 21228,
#  'urgent': 91229,
#  'response': 77872,
#  'thanks': 87167,
#  'faithfully': 40594,
#  'deathtospamdeathtospamdeathtospam': 32727,
#  'sf': 81472,
#  'sponsored': 83683,
#  'thinkgeek': 87330,
#  'welcome': 95137,
#  'geek': 44185,
#  'heaven': 47106,
#  '_______________________________________________': 14696,
#  'spamassassin': 83404,
#  'sightings': 82060,
#  'sourceforge': 83308,
#  'https': 48505,
#  '3d': 6385,
#  'man': 60585,
#  'endowed': 38524,
#  'hammer': 46556,
#  'equipped': 38987,
#  'job': 54598,
#  'short': 81854,
#  'totally': 88271,
#  'methods': 61740,
#  'guaranteed': 45873,
#  '163': 2494,
#  '187': 2757,
#  '47': 8247,
#  'cgi': 27613,
#  'bin': 23627,
#  'php': 71365,
#  '004': 233,
#  'come': 29436,
#  '21doctype': 3986,
#  '22': 3997,
#  'w3c': 93790,
#  'dtd': 36354,
#  'transitional': 88580,
#  '3dcontent': 6908,
#  '22text': 4193,
#  '3dwindows': 7297,
#  '252': 4451,
#  '7b': 11581,
#  'decoration': 32851,
#  '7d': 11648,
#  'active': 16914,
#  'visited': 92923,
#  'hover': 48278,
#  '230033ff': 4221,
#  'underline': 90554,
#  '22mshtml': 4172,
#  '2713': 4634,
#  '1100': 1800,
#  '3dgenerator': 6987,
#  '23000000': 4217,
#  'vlink': 93067,
#  '23ffffff': 4327,
#  'bordercolor': 24584,
#  '233366cc': 4251,
#  '3d4': 6607,
#  '3d15': 6482,
#  '3dcenter': 6892,
#  '22arial': 4133,
#  '23ffff': 4326,
#  'ff': 41231,
#  '3d6': 6669,
#  'immediate': 51251,
#  'release': 77330,
#  '3d3': 6570,
#  '3d2': 6525,
#  'cal': 26476,
#  'bay': 22581,
#  'stock': 84388,
#  'symbol': 85624,
#  'cbyi': 27103,
#  'analyst': 19149,
#  '22strong': 4191,
#  'buy': 25611,
#  'recommendations': 76859,
#  'sev': 81424,
#  'eral': 39016,
#  'advisory': 17376,
#  'newsletters': 65067,
#  'picking': 71499,
#  'filed': 41529,
#  'traded': 88485,
#  'otcbb': 68288,
#  'prices': 73143,
#  'historically': 47649,
#  'companies': 29576,
#  'listed': 58706,
#  'larger': 57541,
#  'trading': 88500,
#  'exhange': 39797,
#  'aroun': 20177,
#  '30': 5593,
#  'a2': 15438,
#  'skyrocket': 82509,
#  '242': 4363,
#  '66': 10344,
#  '243': 4371,
#  'near': 64701,
#  'futur': 43327,
#  'acquire': 16861,
#  'postion': 72620,
#  'ont': 67700,
#  'reasons': 76710,
#  'invest': 52586,
#  'li': 58293,
#  'profitable': 73387,
#  'debt': 32754,
#  'track': 88465,
#  'beat': 22829,
#  'ear': 37240,
#  'nings': 65349,
#  'estimates': 39274,
#  'increased': 51583,
#  'revenue': 78062,
#  'annually': 19369,
#  '21': 3894,
#  'fastest': 40741,
#  'growing': 45726,
#  'distributors': 34503,
#  'environmental': 38793,
#  'safety': 80083,
#  'equipment': 38984,
#  'instruments': 52232,
#  'excellent': 39680,
#  'management': 60602,
#  'team': 86598,
#  'exclu': 39718,
#  'sive': 82329,
#  'contracts': 30301,
#  'impressive': 51383,
#  'client': 28742,
#  'ir': 52878,
#  'force': 42323,
#  'anheuser': 19273,
#  'busch': 25534,
#  'chevron': 27936,
#  'refining': 77081,
#  'mitsubishi': 62372,
#  'heavy': 47112,
#  'industries': 51746,
#  'ge': 44157,
#  'energy': 38554,
#  'research': 77752,
#  '3darial': 6833,
#  'rapidly': 76309,
#  'industry': 51748,
#  'st': 83997,
#  'rong': 78920,
#  'revenues': 78063,
#  'exceed': 39670,
#  '24900': 4397,
#  'indicate': 51683,
#  'th': 87142,
#  '2425': 4365,
#  'billion': 23614,
#  '22smell': 4189,
#  'technology': 86654,
#  'end': 38496,
#  '2003': 3652,
#  'congratulations': 29995,
#  'subscribers': 84841,
#  'took': 88155,
#  'advantag': 17322,
#  'recommendation': 76858,
#  'nxlc': 66413,
#  'rallied': 76231,
#  '247': 4387,
#  '2411': 4359,
#  '73': 11215,
#  '22http': 4156,
#  'quote': 75613,
#  'morningstar': 62991,
#  'timeframe': 87631,
#  '3dy': 7313,
#  'exchangeid': 39705,
#  'ticker': 87543,
#  '3dcbyi': 6885,
#  '230000ff': 4219,
#  '23ff0000': 4324,
#  'removes': 77493,
#  'honere': 48079,
#  '22mailto': 4163,
#  'hon': 48072,
#  'ey9531': 40123,
#  '40btamail': 7902,
#  'cn': 29033,
#  'honey9531': 48084,
#  '40mail': 7917,
#  '3d1': 6417,
#  'certain': 27468,
#  'statements': 84183,
#  'contained': 30223,
#  'news': 65033,
#  'forward': 42510,
#  'looking': 59228,
#  'meaning': 61365,
#  'securities': 81025,
#  'litigation': 58757,
#  'reform': 77096,
#  '1995': 2915,
#  'identified': 49997,
#  'su': 84737,
#  'ch': 27659,
#  'terms': 86896,
#  '22expect': 4145,
#  '22believe': 4136,
#  '22may': 4166,
#  '22will': 4211,
#  '22intend': 4157,
#  'simila': 82152,
#  'registered': 77179,
#  'investment': 52605,
#  'advisor': 17373,
#  'broker': 25097,
#  'dealer': 32706,
#  'offe': 67147,
#  'sell': 81130,
#  'compan': 29575,
#  'ies': 50243,
#  'profiled': 73378,
#  'purchased': 74124,
#  'sold': 83121,
#  'individuals': 51723,
#  'entities': 38735,
#  'hat': 46783,
#  'learn': 57899,
#  'paid': 69203,
#  '2427': 4367,
#  '000': 1,
#  'cash': 26894,
#  'par': 69356,
#  'ty': 89341,
#  'publish': 74027,
#  'report': 77630,
#  'investing': 52602,
#  'se': 80884,
#  ...}

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features, data.CATEGORY,
                                                    test_size=0.3, random_state=88)

# %%
all_features.shape
# Out:
# (5796, 102694)

# %%
all_features
# Out:
# <5796x102694 sparse matrix of type '<class 'numpy.int64'>'
# 	with 704684 stored elements in Compressed Sparse Row format>

# %%
classifier = MultinomialNB()

# %%
classifier.fit(X_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
nr_correct = (y_test == classifier.predict(X_test)).sum()

# %%
print(f'{nr_correct} documents classfied correctly')
# Out:
# 1650 documents classfied correctly

# %%
nr_incorrect = y_test.size - nr_correct
nr_incorrect
# Out:
# 89

# %%
fraction_worng = nr_incorrect/(nr_correct + nr_incorrect)
print(f'{1-fraction_worng:.2},accuracy of the model')
# Out:
# 0.95,accuracy of the model

# %%
from sklearn.metrics import recall_score,precision_score,confusion_matrix,classification_report,f1_score

# %%
recall_score(y_test,classifier.predict(X_test))
# Out:
# 0.8453038674033149

# %%
precision_score(y_test,classifier.predict(X_test))
# Out:
# 0.9892241379310345

# %%
confusion_matrix(y_test,classifier.predict(X_test))
# Out:
# array([[1191,    5],
#        [  84,  459]], dtype=int64)

# %%
f1_score(y_test,classifier.predict(X_test))
# Out:
# 0.9116186693147964

# %%
example = ['could you please help me with the project for tommoro',
          'These plots were generated with the default matplotlib parameters,plus a default colormap that was set to gray-scale and',
          'get viagra for free now!',
          'need a mortgage? Replay to arrange a call with a specilist and get a quote']

# %%
doc_term_matrix = vectorizer.transform(example)

# %%
classifier.predict(doc_term_matrix)
# Out:
# array([0, 0, 1, 1], dtype=int64)
